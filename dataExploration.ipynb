# %%
from DataVis import DataVisualization as DV

explore = DV('ASL', 'ASL/asl_alphabet_train', 'ASL/asl_alphabet_test', 'models/best_model.h5', 'trainHistoryDict')
# Out:
# WARNING:tensorflow:From c:\Users\jsphe\OneDrive\Documents\CPSC542\.venv\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# Found 60900 validated image filenames belonging to 29 classes.
# Found 13050 validated image filenames belonging to 29 classes.
# Found 13050 validated image filenames belonging to 29 classes.
# WARNING:tensorflow:From c:\Users\jsphe\OneDrive\Documents\CPSC542\.venv\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From c:\Users\jsphe\OneDrive\Documents\CPSC542\.venv\Lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.

# %% [markdown]
# Exploration of Dataset:

# %%
print('Train Dataframe')
print(explore.train_df.shape)

print('Validation Dataframe')
print(explore.validation_df.shape)

print('Test Dataframe')
print(explore.test_df.shape)
# Out:
# Train Dataframe
# (60900, 2)
# Validation Dataframe
# (13050, 2)
# Test Dataframe
# (13050, 2)

# %%
print('Train Dataframe')
print(explore.train_df.info())

print('Validation Dataframe')
print(explore.validation_df.info())

print('Test Dataframe')
print(explore.test_df.info())
# Out:
# Train Dataframe
# <class 'pandas.core.frame.DataFrame'>
# Index: 60900 entries, 62878 to 51495
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Filepath  60900 non-null  object
#  1   Label     60900 non-null  object
# dtypes: object(2)
# memory usage: 1.4+ MB
# None
# Validation Dataframe
# <class 'pandas.core.frame.DataFrame'>
# Index: 13050 entries, 74399 to 48221
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Filepath  13050 non-null  object
#  1   Label     13050 non-null  object
# dtypes: object(2)
# memory usage: 305.9+ KB
# None
# Test Dataframe
# <class 'pandas.core.frame.DataFrame'>
# Index: 13050 entries, 53143 to 12670
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Filepath  13050 non-null  object
#  1   Label     13050 non-null  object
# dtypes: object(2)
# ...

# %%
print('Train Dataframe')
print(explore.train_df.describe())

print('Validation Dataframe')
print(explore.validation_df.describe())

print('Test Dataframe')
print(explore.test_df.describe())
# Out:
# Train Dataframe
#                                  Filepath  Label
# count                               60900  60900
# unique                              60900     29
# top     ASL\asl_alphabet_train\J\J838.jpg      J
# freq                                    1   2100
# Validation Dataframe
#                                  Filepath  Label
# count                               13050  13050
# unique                              13050     29
# top     ASL\asl_alphabet_train\I\I424.jpg      I
# freq                                    1    450
# Test Dataframe
#                                      Filepath  Label
# count                                   13050  13050
# unique                                  13050     29
# top     ASL\asl_alphabet_train\del\del514.jpg    del
# freq                                        1    450

# %%
print('Train Dataframe')
class_counts = explore.train_df['Label'].value_counts()
print(class_counts)

print('Validation Dataframe')
class_counts = explore.validation_df['Label'].value_counts()
print(class_counts)

print('Test Dataframe')
class_counts = explore.test_df['Label'].value_counts()
print(class_counts)
# Out:
# Train Dataframe
# Label
# J          2100
# N          2100
# F          2100
# T          2100
# M          2100
# del        2100
# R          2100
# D          2100
# O          2100
# G          2100
# H          2100
# S          2100
# U          2100
# I          2100
# Z          2100
# P          2100
# K          2100
# L          2100
# B          2100
# W          2100
# V          2100
# nothing    2100
# A          2100
# space      2100
# X          2100
# Y          2100
# E          2100
# C          2100
# Q          2100
# Name: count, dtype: int64
# Validation Dataframe
# Label
# I          450
# K          450
# nothing    450
# S          450
# Z          450
# M          450
# V          450
# Y          450
# X          450
# W          450
# B          450
# U          450
# Q          450
# O          450
# space      450
# F          450
# N          450
# C          450
# R          450
# E          450
# G          450
# H          450
# J          450
# ...

# %% [markdown]
# As you can see above, following the train-test-split (70-15-15) each dataset was successfully divided correctly. Each class began with an even number of around 3000 images for each class, thus removing the need to check for class imbalances.

# %%
explore.ImageExamples(6)

# %% [markdown]
# Model Analysis

# %%
explore.basicSummary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ...
#  input_1 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  conv1_pad (ZeroPadding2D)   (None, 230, 230, 3)          0         ['input_1[0][0]']
#
#  conv1_conv (Conv2D)         (None, 112, 112, 64)         9472      ['conv1_pad[0][0]']
#
#  pool1_pad (ZeroPadding2D)   (None, 114, 114, 64)         0         ['conv1_conv[0][0]']
#
#  pool1_pool (MaxPooling2D)   (None, 56, 56, 64)           0         ['pool1_pad[0][0]']
#
#  conv2_block1_preact_bn (Ba  (None, 56, 56, 64)           256       ['pool1_pool[0][0]']
#  tchNormalization)
#
#  conv2_block1_preact_relu (  (None, 56, 56, 64)           0         ['conv2_block1_preact_bn[0][0]
#  Activation)                                                        ']
#
# ...

# %%
explore.AccLoss()

# %% [markdown]
# We can see the model performed exceptionally on the dataset, with values only improving throughout the epochs.

# %%
explore.predFolder('testImages')
# Out:
# ...
# 1/1 [==============================] - 0s 64ms/step

# %% [markdown]
# This should be JOE, displaying the models difficulty working with new examples of data.

# %%
explore.occlusionMap()
# Out:
# ...
# 1/1 [==============================] - 0s 71ms/step
